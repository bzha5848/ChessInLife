# %%
u = 'bzha5848'
r = 'YOLOFun'
g = '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'
# !git clone https://{g}@github.com/{u}/{r}
# %cd YOLOFun
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

u = 'bzha5848'
r = 'ChessInLife'
g = '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'
# !git clone https://{g}@github.com/{u}/{r}
# Out:
# Cloning into 'YOLOFun'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 185 (delta 81), reused 150 (delta 53), pack-reused 0
# Receiving objects: 100% (185/185), 849.74 KiB | 11.04 MiB/s, done.
# Resolving deltas: 100% (81/81), done.
# /content/YOLOFun
#      |████████████████████████████████| 145 kB 19.1 MB/s
#      |████████████████████████████████| 178 kB 66.3 MB/s
#      |████████████████████████████████| 67 kB 6.2 MB/s
#      |████████████████████████████████| 54 kB 3.1 MB/s
#      |████████████████████████████████| 138 kB 68.5 MB/s
#      |████████████████████████████████| 62 kB 1.5 MB/s
# ...
# Cloning into 'ChessInLife'...
# remote: Enumerating objects: 2448, done.
# remote: Total 2448 (delta 0), reused 0 (delta 0), pack-reused 2448
# Receiving objects: 100% (2448/2448), 106.57 MiB | 21.07 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !python train.py --img 416 --batch 8 --epochs 1001 --data /content/YOLOFun/ChessInLife/data.yaml --cfg /content/YOLOFun/models/Basics/yolov5l.yaml --weights yolov5l.pt --hyp /content/YOLOFun/data/hyps/hyp.scratch-high.yaml --save-period 30 --patience 100
# Out:
# train: weights=yolov5l.pt, cfg=/content/YOLOFun/models/Basics/yolov5l.yaml, data=/content/YOLOFun/ChessInLife/data.yaml, hyp=/content/YOLOFun/data/hyps/hyp.scratch-high.yaml, epochs=1001, batch_size=8, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=30, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# fatal: ambiguous argument 'main..origin/master': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# Command 'git rev-list main..origin/master --count' returned non-zero exit status 128.
# ...
